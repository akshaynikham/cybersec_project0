# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('sensor_data.csv')


sampled_df = df.iloc[::100, :] 

plt.scatter(sampled_df['Time'], sampled_df['Temperature'], s=1) # s=1 makes dots tiny
plt.show()
